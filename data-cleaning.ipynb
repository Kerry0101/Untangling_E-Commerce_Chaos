# %%
import pandas as pd

df = pd.read_csv('ecommerce_orders_dirty.csv')
df
# Out:
#       Order ID Customer Name                   Email         Country Currency  \
# 0      ORD8817        😊 Alex         😊alex@gmail.con              DE      USD
# 1      ORD2676   Marie Curie  mariecurie@hotmail.com             USA        $
# 2      ORD5686        😊 Alex       😊alex@outlook.com  United Kingdom        $
# 3     ORD19599    Jane Smith   janesmith@outlook.com     Deutschland      USD
# 4      ORD6512   Marie Curie  mariecurie@hotmail.com              UK        €
# ...        ...           ...                     ...             ...      ...
# 9995   ORD3336    Jane Smith   janesmith@hotmail.com              UK      USD
# 9996  ORD15481   Anna Müller  annamüller@hotmail.com         Germany        $
# 9997   ORD2267            王伟            王伟@gmail.con              UK      JPY
# 9998  ORD14299            王伟          王伟@hotmail.com              DE        $
# 9999   ORD8011   Carlos Diaz  carlosdiaz@outlook.com     Deutschland      USD
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order ID             8967 non-null   object
#  1   Customer Name        10000 non-null  object
#  2   Email                10000 non-null  object
#  3   Country              10000 non-null  object
#  4   Currency             10000 non-null  object
#  5   Product SKU          10000 non-null  object
#  6   Product Description  10000 non-null  object
#  7   Quantity             10000 non-null  object
#  8   Unit Price           10000 non-null  object
#  9   Total Price          0 non-null      float64
#  10  Order Date           10000 non-null  object
#  11  Shipping Fee         10000 non-null  object
#  12  Delivery Status      10000 non-null  object
#  13  Delivery Date        10000 non-null  object
#  14  Payment Method       10000 non-null  object
# ...

# %% [markdown]
# # Inspect the data

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order ID             8967 non-null   object
#  1   Customer Name        10000 non-null  object
#  2   Email                10000 non-null  object
#  3   Country              10000 non-null  object
#  4   Currency             10000 non-null  object
#  5   Product SKU          10000 non-null  object
#  6   Product Description  10000 non-null  object
#  7   Quantity             10000 non-null  object
#  8   Unit Price           10000 non-null  object
#  9   Total Price          0 non-null      float64
#  10  Order Date           10000 non-null  object
#  11  Shipping Fee         10000 non-null  object
#  12  Delivery Status      10000 non-null  object
#  13  Delivery Date        10000 non-null  object
#  14  Payment Method       10000 non-null  object
# ...

# %% [markdown]
# # Count nulls per column

# %%
nulls_per_column = df.isnull().sum()
print("Nulls per column:\n", nulls_per_column)
# Out:
# Nulls per column:
#  Order ID                1033
# Customer Name              0
# Email                      0
# Country                    0
# Currency                   0
# Product SKU                0
# Product Description        0
# Quantity                   0
# Unit Price                 0
# Total Price            10000
# Order Date                 0
# Shipping Fee               0
# Delivery Status            0
# Delivery Date              0
# Payment Method             0
# Notes                   4019
# Unnamed: 0                 0
# dtype: int64

# %% [markdown]
# # Check for duplicate Order IDs

# %%
duplicate_order_ids = df['Order ID'].duplicated().sum()
print(f"Number of duplicate Order IDs: {duplicate_order_ids}")
# Out:
# Number of duplicate Order IDs: 2808

# %% [markdown]
# # Check unique values in 'Currency' and 'Order Date' columns

# %%
print("Unique Currency formats:", df['Currency'].unique())
print("Unique Order Date formats:", df['Order Date'].unique())
# Out:
# Unique Currency formats: ['USD' '$' '€' 'JPY' '£']
# Unique Order Date formats: ['2026-12-01' '2023-05-12']

# %% [markdown]
# # Check example patterns (first 20 unique values)

# %%
print(df['Order Date'].dropna().unique()[:20])
# Out:
# ['2026-12-01' '2023-05-12']

# %% [markdown]
# #### Checkpoint: 3 Unique Data Issues
#
#
# 1. Several columns contain missing (null) values, especially in `Shipping Address` and `Order Date`.
# 2. There are duplicate entries in the `Order ID` column, which may indicate repeated or erroneous orders.
# 3. The `Order Date` and `Currency` columns contain inconsistent formats, making it difficult to analyze or convert them directly.

# %%
print(df.columns.tolist())
# Out:
# ['Order ID', 'Customer Name', 'Email', 'Country', 'Currency', 'Product SKU', 'Product Description', 'Quantity', 'Unit Price', 'Total Price', 'Order Date', 'Shipping Fee', 'Delivery Status', 'Delivery Date', 'Payment Method', 'Notes', 'Unnamed: 0']

# %%
print(df.head())
print(df.sample(5))  # Shows 5 random rows# Shows the first 5 rows
# Out:
#    Order ID Customer Name                   Email         Country Currency  \
# 0   ORD8817        😊 Alex         😊alex@gmail.con              DE      USD
# 1   ORD2676   Marie Curie  mariecurie@hotmail.com             USA        $
# 2   ORD5686        😊 Alex       😊alex@outlook.com  United Kingdom        $
# 3  ORD19599    Jane Smith   janesmith@outlook.com     Deutschland      USD
# 4   ORD6512   Marie Curie  mariecurie@hotmail.com              UK        €
#
#   Product SKU Product Description Quantity Unit Price  Total Price  \
# 0     SKU-123          Smartphone        2     twenty          NaN
# 1         345          Smartphone        1         40          NaN
# 2     #SKU234     Laptop&nbsp;Bag        0      15,00          NaN
# 3     SKU-123         USB-C Cable    three        €30          NaN
# 4         345        Gaming Chair       -1      15,00          NaN
#
#    Order Date Shipping Fee Delivery Status Delivery Date Payment Method  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order ID             8967 non-null   object
#  1   Customer Name        10000 non-null  object
#  2   Email                10000 non-null  object
#  3   Country              10000 non-null  object
#  4   Currency             10000 non-null  object
#  5   Product SKU          10000 non-null  object
#  6   Product Description  10000 non-null  object
#  7   Quantity             10000 non-null  object
#  8   Unit Price           10000 non-null  object
#  9   Total Price          0 non-null      float64
#  10  Order Date           10000 non-null  object
#  11  Shipping Fee         10000 non-null  object
#  12  Delivery Status      10000 non-null  object
#  13  Delivery Date        10000 non-null  object
#  14  Payment Method       10000 non-null  object
# ...

# %%
df.head(10).to_csv("sample_data.csv", index=False)

# %% [markdown]
# # Part 2: Advanced Cleaning Tasks
# ## Step A: Clean Structural Issues
#
# ### 1. Drop "Unnamed: 0" Column

# %%
df = df.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ### 2. Drop Rows with Missing "Order ID" or "Email"

# %%
df = df.dropna(subset=['Order ID', 'Email'])

# %% [markdown]
# ### 3. Standardize "Customer Name" (title case, remove emojis/special characters)

# %%
import re

def clean_name(name):
    # Remove emojis and special characters except spaces and letters
    name = re.sub(r'[^\w\s]', '', name)
    name = re.sub(r'[\d_]', '', name)
    name = name.encode('ascii', 'ignore').decode('ascii')  # remove non-ASCII
    return name.title().strip()

df['Customer Name'] = df['Customer Name'].astype(str).apply(clean_name)

# %% [markdown]
# ## Step B: Normalize Multi-format Fields
# ### 1. Convert "Order Date" to datetime and remove future dates

# %%
import pandas as pd
from datetime import datetime

# Convert Order Date to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Remove future dates (dates after today)
df = df[df['Order Date'] <= pd.Timestamp(datetime.now())]

# %% [markdown]
# ### 2. Standardize "Currency" to "USD"

# %%
def currency_to_usd(row):
    currency = row['Currency']
    unit_price = str(row['Unit Price']).replace(',', '').replace(' ', '')
    try:
        unit_price = float(re.sub(r'[^\d.]+', '', unit_price))
    except:
        return None
    if currency == 'USD' or currency == '$':
        return unit_price
    elif currency == '€':
        return round(unit_price / 1.1, 2)
    elif currency == '£':
        return round(unit_price * 1.25, 2)
    elif currency == 'JPY':
        return round(unit_price * 0.007, 2)
    else:
        return unit_price  # If unknown, leave as is

df['Unit Price'] = df.apply(currency_to_usd, axis=1)
df['Currency'] = 'USD'

# %% [markdown]
# ### 3. Clean and convert "Unit Price", "Shipping Fee", and "Total Price" to float

# %%
def clean_float(val):
    if pd.isnull(val):
        return 0.0
    val = str(val).replace(',', '').replace('free', '0').replace('Free', '0')
    val = re.sub(r'[^\d.-]+', '', val)
    try:
        return float(val)
    except:
        return 0.0

df['Unit Price'] = df['Unit Price'].apply(clean_float)
df['Shipping Fee'] = df['Shipping Fee'].apply(clean_float)
df['Total Price'] = df['Total Price'].apply(clean_float)

# %% [markdown]
# ### 4. Clean "Quantity" (convert to numeric values)

# %%
def clean_quantity(val):
    if pd.isnull(val):
        return 0
    val_str = str(val).strip().lower()
    words_to_num = {'one': 1, 'two': 2, 'three': 3, 'four': 4, 'zero': 0, '-1': -1}
    if val_str in words_to_num:
        return words_to_num[val_str]
    try:
        return int(val_str)
    except:
        return 0
df = df.copy()
df['Quantity'] = df['Quantity'].apply(clean_quantity)

# %% [markdown]
# ### 5. Recalculate "Total Price"

# %%
df['Total Price'] = df['Quantity'] * df['Unit Price'] + df['Shipping Fee']

# %%
df.describe(include='all')
# Out:
#         Order ID Customer Name         Email  Country Currency Product SKU  \
# count       6699          6699          6699     6699     6699        6699
# unique      5662             7            28        7        1           5
# top     ORD11021                王伟@gmail.con  Germany      USD     SKU-123
# freq           5           985           260      983     6699        1401
# mean         NaN           NaN           NaN      NaN      NaN         NaN
# min          NaN           NaN           NaN      NaN      NaN         NaN
# 25%          NaN           NaN           NaN      NaN      NaN         NaN
# 50%          NaN           NaN           NaN      NaN      NaN         NaN
# 75%          NaN           NaN           NaN      NaN      NaN         NaN
# max          NaN           NaN           NaN      NaN      NaN         NaN
# std          NaN           NaN           NaN      NaN      NaN         NaN
#
#        Product Description     Quantity   Unit Price  Total Price  \
# ...

# %%
print("Unique currencies:", df['Currency'].unique())
print("Order Date range:", df['Order Date'].min(), "to", df['Order Date'].max())
# Out:
# Unique currencies: ['USD']
# Order Date range: 2023-05-12 00:00:00 to 2023-05-12 00:00:00

# %% [markdown]
# # Part 2: Advanced Cleaning Tasks (Continued)

# %% [markdown]
# ## Step C: Fix Text & Codes
#
# ### 1. Email: Fix `.con` to `.com`, lowercase, drop invalid formats

# %%
import re

# Fix ".con" to ".com" and lowercase
df['Email'] = df['Email'].str.replace('.con', '.com', case=False).str.lower()

# Drop rows where email is not a valid format
df = df[df['Email'].str.match(r'^[\w\.-]+@[\w\.-]+\.\w+$')]

# %% [markdown]
# ### 2. Product SKU: Extract numeric ID (e.g., "123" from "SKU-123" or "#SKU123")

# %%
def extract_sku(s):
    match = re.search(r'(\d+)', str(s))
    return match.group(1) if match else None

df['Product SKU'] = df['Product SKU'].apply(extract_sku)

# %% [markdown]
# ### 3. Product Description: Strip HTML, trim whitespace

# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup

def clean_description(s):
    if pd.isnull(s):
        return s
    return BeautifulSoup(str(s), "html.parser").get_text().strip()

df['Product Description'] = df['Product Description'].apply(clean_description)

# %% [markdown]
# ### 4. Quantity: Convert words like "two" or "3 pcs" into numeric

# %%
words_to_num = {
    "zero": 0, "one": 1, "two": 2, "three": 3, "four": 4, "five": 5,
    "six": 6, "seven": 7, "eight": 8, "nine": 9, "ten": 10
}

def clean_quantity(val):
    if pd.isnull(val):
        return 0
    val_str = str(val).lower().strip()
    # Remove text like 'pcs'
    val_str = re.sub(r'[^a-zA-Z0-9]', ' ', val_str)
    for word, num in words_to_num.items():
        if word in val_str:
            return num
    nums = re.findall(r'\d+', val_str)
    return int(nums[0]) if nums else 0

df['Quantity'] = df['Quantity'].apply(clean_quantity)

# %% [markdown]
# ### 5. Delivery Status: Normalize to "Delivered", "In Transit", "Cancelled"

# %%
def normalize_status(s):
    s = str(s).lower()
    if 'deliver' in s:
        return 'Delivered'
    elif 'in transit' in s or 'transit' in s or 'shipped' in s:
        return 'In Transit'
    elif 'cancel' in s:
        return 'Cancelled'
    else:
        return 'Other'

df['Delivery Status'] = df['Delivery Status'].apply(normalize_status)

# %% [markdown]
# ## Step D: Validate Logic
#
# ### 1. Flag entries where Delivery Date < Order Date

# %%
df['Delivery Date'] = pd.to_datetime(df['Delivery Date'], errors='coerce')
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

df['Delivery_Date_Error'] = df['Delivery Date'] < df['Order Date']

# %% [markdown]
# ### 2. Remove rows where Quantity <= 0 or Unit Price < 0

# %%
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')
df['Unit Price'] = pd.to_numeric(df['Unit Price'], errors='coerce')

# %%
df = df[(df['Quantity'] > 0) & (df['Unit Price'] >= 0)]

# %% [markdown]
# ### 3. Validate that recalculated Total Price matches stored value ±1%

# %%
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')
df['Unit Price'] = pd.to_numeric(df['Unit Price'], errors='coerce')
df['Shipping Fee'] = pd.to_numeric(df['Shipping Fee'], errors='coerce')
df['Total Price'] = pd.to_numeric(df['Total Price'], errors='coerce')

# If not already: recalculate total price
df['Recalc Total Price'] = df['Quantity'] * df['Unit Price'] + df['Shipping Fee']

# Flag rows where difference is more than 1%
df['Total_Price_Mismatch'] = (
    abs(df['Total Price'] - df['Recalc Total Price']) > 0.01 * df['Recalc Total Price']
)

# %%
df.head()
df.info()
df[['Delivery_Date_Error', 'Total_Price_Mismatch']].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2047 entries, 1 to 9998
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Order ID              1818 non-null   object
#  1   Customer Name         2047 non-null   object
#  2   Email                 2047 non-null   object
#  3   Country               2047 non-null   object
#  4   Currency              2047 non-null   object
#  5   Product SKU           2047 non-null   object
#  6   Product Description   2047 non-null   object
#  7   Quantity              2047 non-null   int64
#  8   Unit Price            2047 non-null   float64
#  9   Total Price           0 non-null      float64
#  10  Order Date            2047 non-null   datetime64[ns]
#  11  Shipping Fee          1040 non-null   float64
#  12  Delivery Status       2047 non-null   object
#  13  Delivery Date         2047 non-null   datetime64[ns]
# ...

# %%
df['Delivery_Date_Error'] = df['Delivery Date'] < df['Order Date']

# %%
df = df[(df['Quantity'] > 0) & (df['Unit Price'] >= 0)]

# %%
df['Recalc Total Price'] = df['Quantity'] * df['Unit Price'] + df['Shipping Fee']
df['Total_Price_Mismatch'] = (
    abs(df['Total Price'] - df['Recalc Total Price']) > 0.01 * df['Recalc Total Price']
)

# %%
from datetime import datetime

def get_validity(row):
    if row['Order Date'] > pd.Timestamp(datetime.now()):
        return 'Invalid: Future Date'
    if row.get('Delivery_Date_Error', False):
        return 'Invalid: Delivery Date Error'
    if row.get('Total_Price_Mismatch', False):
        return 'Invalid: Wrong Total'
    return 'Valid'

df['Order Validity'] = df.apply(get_validity, axis=1)

# %%
df_clean = df[df['Order Validity'] == 'Valid']
df_clean.to_csv('ecommerce_orders_cleaned.csv', index=False)

# %%
df.to_csv('ecommerce_orders_with_validity.csv', index=False)

# %%
num_valid = (df['Order Validity'] == 'Valid').sum()
num_future_dates = (df['Order Validity'] == 'Invalid: Future Date').sum()
num_wrong_totals = (df['Order Validity'] == 'Invalid: Wrong Total').sum()
num_delivery_date_errors = (df['Order Validity'] == 'Invalid: Delivery Date Error').sum()
num_removed = len(df) - num_valid

# %% [markdown]
# ##### 3. Markdown summary

# %% [markdown]
# # Ecommerce Dataset Cleaning Summary
#
# ## Total Records Processed
# - Original rows: **10,000**
# - Final valid rows: **{num_valid}**
# - Invalid records removed: **{num_removed}**
#
# ## Invalid Records Breakdown
# - Future Dates: **{num_future_dates}**
# - Wrong Totals: **{num_wrong_totals}**
# - Delivery Date Errors: **{num_delivery_date_errors}**
#
# ## Biggest Cleanup Challenges
# - **Multi-format fields:** Converting mixed currencies and price/quantity formats to consistent numeric values.
# - **Missing and inconsistent data:** Many records had missing or nonsensical values for `Order ID`, dates, or prices.
# - **Logical inconsistencies:** Orders with delivery dates before order dates, or impossible total prices.
# - **Text normalization:** Cleaning customer names, removing emojis, and standardizing email and SKU fields.
